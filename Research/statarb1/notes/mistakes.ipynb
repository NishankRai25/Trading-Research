# %% [markdown]
# # Mistakes For next time
#
# 1) when starting off, really understand and perfect the baseline model first then get into adding more, i started here with pca and ou but before i even perfected that i started creating more strategys to add on
#
# 2) Plan based on failures of baseline not just by pure theory, before i created baseline #1 i had idea what i wnated for baseline #2 i should plan baseline #2 based on what baseline #1 fails in
